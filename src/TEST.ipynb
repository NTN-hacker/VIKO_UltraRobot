# %%
import plotly.express as px 
import cv2

img = cv2.imread('../p1.png')

px.imshow(img)

# %%
img1 = cv2.imread('../p1.png')
img2 = cv2.imread('../p2.png')

# %%
get_point(img1)
# Out:
# (0.0, 0.0)
