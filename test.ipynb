# %%
from config import config
from lib import vision

# %%
obj = vision.VisionModule()
# Out:
# acA2440-35uc 22481496
# ---------------------------------------------------------------------------
# RuntimeException                          Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 obj = vision.VisionModule()
#
# File d:\Quan\roboDK\Vision-Machine-collab-Nhan\VIKO_UltraRobot\lib\vision.py:45, in VisionModule.__init__(self)
#      42     self.model_name = device.GetModelName()
#      44 self.camera = py.InstantCamera()
# ---> 45 self.camera.Attach(tl_factory.CreateDevice(devices[0]))
#      46 self.runningStatus       = False
#      47 self.thread              = None
#
# File c:\ProgramData\anaconda3\envs\robodk\lib\site-packages\pypylon\pylon.py:1732, in TlFactory.CreateDevice(self, *args)
#    1722 def CreateDevice(self, *args):
#    1723     r"""
#    1724
#    1725
#    (...)
#    1730
#    1731     """
# -> 1732     return _pylon.TlFactory_CreateDevice(self, *args)
#
# RuntimeException: Failed to open device '\\?\usb#vid_2676&pid_ba02&mi_00#6&f4aabb8&0&0000#{79bfeeca-947f-11e1-bc58-001b2163ef96}' for XML file download. Error: 'Device is exclusively opened by another client.' : RuntimeException thrown (file 'pylonusbtl.cpp', line 497)

# %%
obj._start_()

# %%
obj.settingParameter()

# %%
obj._getImage_()
# Out:
# Serial No:acA2440-35uc_22481496
# Serial No:acA2440-35uc_22481496

# %%
img = obj.save_image()
# Out:
# Total time for saving: 3.324989

# %%
obj.load_model()

# %%
masks = obj._getCoordinate_()
# Out:
# 29

# %%
import cv2
# img_cvt = cv2.imread('D:\Quan\\roboDK\Vision-Machine-collab-Nhan\VIKO_UltraRobot\Record_2024-04-19\\20240419-124548418601-acA2440-35uc_22481496.png')
img_cvt = img.copy()

# %%
masks
# Out:
# [{'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1489775,
#   'bbox': [899, 67, 883, 1737],
#   'predicted_iou': 1.0363852977752686,
#   'point_coords': [[1032.75, 1568.0]],
#   'stability_score': 0.9921995401382446,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 192179,
#   'bbox': [0, 804, 168, 1234],
#   'predicted_iou': 1.0117361545562744,
#   'point_coords': [[114.75, 1568.0]],
#   'stability_score': 0.9836929440498352,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 36980,
#   'bbox': [0, 1766, 151, 278],
#   'predicted_iou': 1.0059897899627686,
#   'point_coords': [[38.25, 1824.0]],
#   'stability_score': 0.9873182773590088,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3451843,
#   'bbox': [0, 0, 2447, 2043],
#   'predicted_iou': 0.9976884126663208,
#   'point_coords': [[1644.75, 1888.0]],
#   'stability_score': 0.9689185619354248,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 865043,
#   'bbox': [0, 0, 685, 2041],
#   'predicted_iou': 0.9868414402008057,
#   'point_coords': [[191.25, 1952.0]],
#   'stability_score': 0.9754414558410645,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 6387,
#   'bbox': [1816, 1816, 98, 84],
#   'predicted_iou': 0.9867875576019287,
#   'point_coords': [[1874.25, 1824.0]],
#   'stability_score': 0.9937607049942017,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 536963,
#   'bbox': [1898, 0, 549, 1086],
#   'predicted_iou': 0.9866801500320435,
#   'point_coords': [[1950.75, 608.0]],
#   'stability_score': 0.9505382776260376,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 155369,
#   'bbox': [1277, 66, 193, 1736],
#   'predicted_iou': 0.9861899614334106,
#   'point_coords': [[1338.75, 160.0]],
#   'stability_score': 0.9523758888244629,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 544800,
#   'bbox': [1906, 0, 541, 2032],
#   'predicted_iou': 0.9805383086204529,
#   'point_coords': [[1950.75, 352.0]],
#   'stability_score': 0.9564839601516724,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 160478,
#   'bbox': [1282, 68, 134, 1736],
#   'predicted_iou': 0.977939248085022,
#   'point_coords': [[1338.75, 1568.0]],
#   'stability_score': 0.9537250399589539,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 394203,
#   'bbox': [531, 910, 384, 1130],
#   'predicted_iou': 0.9716601371765137,
#   'point_coords': [[726.75, 1696.0]],
#   'stability_score': 0.963166356086731,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 490378,
#   'bbox': [0, 0, 523, 1020],
#   'predicted_iou': 0.9669914245605469,
#   'point_coords': [[420.75, 992.0]],
#   'stability_score': 0.9832766652107239,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 494845,
#   'bbox': [0, 0, 523, 1736],
#   'predicted_iou': 0.9643028974533081,
#   'point_coords': [[267.75, 160.0]],
#   'stability_score': 0.9546672105789185,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 28005,
#   'bbox': [532, 908, 328, 123],
#   'predicted_iou': 0.9595909118652344,
#   'point_coords': [[726.75, 992.0]],
#   'stability_score': 0.9674126505851746,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3985,
#   'bbox': [879, 34, 91, 81],
#   'predicted_iou': 0.9513368010520935,
#   'point_coords': [[879.75, 96.0]],
#   'stability_score': 0.9801340699195862,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 363091,
#   'bbox': [10, 1014, 658, 1027],
#   'predicted_iou': 0.9388360381126404,
#   'point_coords': [[267.75, 1120.0]],
#   'stability_score': 0.9644277095794678,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 11677,
#   'bbox': [1816, 1815, 99, 226],
#   'predicted_iou': 0.9379982948303223,
#   'point_coords': [[1874.25, 1888.0]],
#   'stability_score': 0.9530493021011353,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 13549,
#   'bbox': [1524, 0, 220, 62],
#   'predicted_iou': 0.9286369681358337,
#   'point_coords': [[1721.25, 32.0]],
#   'stability_score': 0.9731225967407227,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4241,
#   'bbox': [1840, 1940, 75, 101],
#   'predicted_iou': 0.9214513301849365,
#   'point_coords': [[1874.25, 1952.0]],
#   'stability_score': 0.9691057205200195,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 23142,
#   'bbox': [0, 1606, 150, 230],
#   'predicted_iou': 0.9204535484313965,
#   'point_coords': [[114.75, 1696.0]],
#   'stability_score': 0.9630304574966431,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 194750,
#   'bbox': [0, 13, 171, 2030],
#   'predicted_iou': 0.908478856086731,
#   'point_coords': [[114.75, 1696.0]],
#   'stability_score': 0.9630956649780273,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2271,
#   'bbox': [1321, 1656, 54, 53],
#   'predicted_iou': 0.9062477946281433,
#   'point_coords': [[1338.75, 1696.0]],
#   'stability_score': 0.9676165580749512,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1260,
#   'bbox': [2250, 535, 39, 40],
#   'predicted_iou': 0.9055524468421936,
#   'point_coords': [[2256.75, 544.0]],
#   'stability_score': 0.9663800001144409,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 30739,
#   'bbox': [0, 805, 167, 198],
#   'predicted_iou': 0.904164731502533,
#   'point_coords': [[114.75, 992.0]],
#   'stability_score': 0.9716851115226746,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3637,
#   'bbox': [2206, 1808, 102, 107],
#   'predicted_iou': 0.902485728263855,
#   'point_coords': [[2256.75, 1888.0]],
#   'stability_score': 0.9682840704917908,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 35857,
#   'bbox': [517, 1846, 394, 197],
#   'predicted_iou': 0.8975841999053955,
#   'point_coords': [[573.75, 1888.0]],
#   'stability_score': 0.9603304266929626,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 35670,
#   'bbox': [517, 1846, 185, 197],
#   'predicted_iou': 0.8968033790588379,
#   'point_coords': [[650.25, 1888.0]],
#   'stability_score': 0.973031759262085,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 8398,
#   'bbox': [777, 9, 193, 121],
#   'predicted_iou': 0.8938106298446655,
#   'point_coords': [[879.75, 96.0]],
#   'stability_score': 0.9523864984512329,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 40985,
#   'bbox': [699, 1849, 216, 194],
#   'predicted_iou': 0.8831000924110413,
#   'point_coords': [[726.75, 1888.0]],
#   'stability_score': 0.9756062030792236,
#   'crop_box': [0, 0, 2448, 2048]}]

# %%
import numpy as np
img_arr = np.asarray(img)

# %%
img_arr.shape
# Out:
# (2048, 2448, 3)

# %%
for mask in masks:
    x, y, w, h = mask['bbox']
    if (x == 899):
        print(mask['bbox'])
        cv2.rectangle(img_arr, (x, y), (x+w, y + h),   (0, 255, 0), thickness= 10)
    # cv2.imshow('Show', img_cvt)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()
# Out:
# [899, 67, 883, 1737]

# %%
import matplotlib.pyplot as plt
plt.imshow(img_arr)

# %%
plt.savefig('Record_2024-04-19/Masks1.png')

# %%
obj._end_()
