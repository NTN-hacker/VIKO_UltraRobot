# %%
from config import config
from lib import vision

# %%
obj = vision.VisionModule()
# Out:
# acA2440-35uc 22481496

# %%
obj._start_()

# %%
obj.settingParameter()

# %%
obj._getImage_()
# Out:
# Serial No:acA2440-35uc_22481496
# Serial No:acA2440-35uc_22481496

# %%
img = obj.save_image()
# Out:
# Total time for saving: 2.862000

# %%
obj.load_model()

# %%
masks = obj._getCoordinate_()
# Out:
# 19

# %%
import cv2
# img_cvt = cv2.imread('D:\Quan\\roboDK\Vision-Machine-collab-Nhan\VIKO_UltraRobot\Record_2024-04-19\\20240419-124548418601-acA2440-35uc_22481496.png')
img_cvt = img.copy()

# %%
masks
# Out:
# [{'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1477231,
#   'bbox': [957, 108, 877, 1735],
#   'predicted_iou': 1.0361162424087524,
#   'point_coords': [[1262.25, 864.0]],
#   'stability_score': 0.9933943152427673,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3465461,
#   'bbox': [0, 0, 2447, 2042],
#   'predicted_iou': 1.0157289505004883,
#   'point_coords': [[191.25, 992.0]],
#   'stability_score': 0.9705785512924194,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 197672,
#   'bbox': [0, 806, 171, 1236],
#   'predicted_iou': 1.0010225772857666,
#   'point_coords': [[114.75, 2016.0]],
#   'stability_score': 0.98997962474823,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 32469,
#   'bbox': [0, 1799, 154, 245],
#   'predicted_iou': 0.9931705594062805,
#   'point_coords': [[114.75, 1888.0]],
#   'stability_score': 0.9846882820129395,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 152930,
#   'bbox': [1341, 111, 107, 1727],
#   'predicted_iou': 0.9885131120681763,
#   'point_coords': [[1415.25, 864.0]],
#   'stability_score': 0.97220379114151,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 427364,
#   'bbox': [520, 911, 401, 1130],
#   'predicted_iou': 0.9841017723083496,
#   'point_coords': [[650.25, 1568.0]],
#   'stability_score': 0.9823789596557617,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 536505,
#   'bbox': [1859, 4, 588, 1076],
#   'predicted_iou': 0.9783874750137329,
#   'point_coords': [[1950.75, 608.0]],
#   'stability_score': 0.9534720778465271,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 21960,
#   'bbox': [17, 1016, 149, 181],
#   'predicted_iou': 0.9774591326713562,
#   'point_coords': [[114.75, 1120.0]],
#   'stability_score': 0.9600160717964172,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 542279,
#   'bbox': [1879, 5, 568, 2027],
#   'predicted_iou': 0.9669948220252991,
#   'point_coords': [[1950.75, 352.0]],
#   'stability_score': 0.9535791873931885,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 24324,
#   'bbox': [1521, 0, 220, 112],
#   'predicted_iou': 0.9669535160064697,
#   'point_coords': [[1644.75, 96.0]],
#   'stability_score': 0.9903877377510071,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 362675,
#   'bbox': [154, 1015, 369, 1027],
#   'predicted_iou': 0.9638428092002869,
#   'point_coords': [[497.25, 2016.0]],
#   'stability_score': 0.9796165227890015,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4892,
#   'bbox': [529, 909, 122, 49],
#   'predicted_iou': 0.9637100100517273,
#   'point_coords': [[573.75, 928.0]],
#   'stability_score': 0.976965069770813,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 362755,
#   'bbox': [153, 1014, 743, 1028],
#   'predicted_iou': 0.9592117667198181,
#   'point_coords': [[344.25, 1952.0]],
#   'stability_score': 0.9778270721435547,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 157566,
#   'bbox': [2269, 1098, 178, 943],
#   'predicted_iou': 0.9586087465286255,
#   'point_coords': [[2333.25, 1760.0]],
#   'stability_score': 0.9699495434761047,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2110,
#   'bbox': [1390, 1692, 51, 52],
#   'predicted_iou': 0.9354616403579712,
#   'point_coords': [[1415.25, 1696.0]],
#   'stability_score': 0.9784037470817566,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 14885,
#   'bbox': [1704, 415, 117, 146],
#   'predicted_iou': 0.9323046803474426,
#   'point_coords': [[1797.75, 480.0]],
#   'stability_score': 0.9614520072937012,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 818,
#   'bbox': [1863, 1679, 32, 37],
#   'predicted_iou': 0.9116040468215942,
#   'point_coords': [[1874.25, 1696.0]],
#   'stability_score': 0.9842615127563477,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 159534,
#   'bbox': [1961, 1096, 486, 946],
#   'predicted_iou': 0.9022165536880493,
#   'point_coords': [[2409.75, 1888.0]],
#   'stability_score': 0.9521721601486206,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 29776,
#   'bbox': [0, 806, 171, 208],
#   'predicted_iou': 0.887096107006073,
#   'point_coords': [[114.75, 992.0]],
#   'stability_score': 0.9748202562332153,
#   'crop_box': [0, 0, 2448, 2048]}]

# %%
import numpy as np
img_arr = np.asarray(img)

# %%
img_arr.shape
# Out:
# (2048, 2448, 3)

# %%
for mask in masks:
    x, y, w, h = mask['bbox']
    if (x == 957):
        print(mask['bbox'])
        cv2.rectangle(img_arr, (x, y), (x+w, y + h),   (0, 255, 0), thickness= 10)
    # cv2.imshow('Show', img_cvt)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()
# Out:
# [957, 108, 877, 1735]

# %%
import matplotlib.pyplot as plt
plt.imshow(img_arr)

# %%
plt.savefig('Record_2024-04-19/Masks1.png')

# %%
obj._end_()
