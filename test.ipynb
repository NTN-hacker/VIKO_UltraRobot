# %%
from config import config
from lib import vision

# %%
obj = vision.VisionModule()
# Out:
# acA2440-35uc 22481496

# %%
obj._start_()

# %%
obj.settingParameter()

# %%
obj._getImage_()
# Out:
# Serial No:acA2440-35uc_22481496
# Serial No:acA2440-35uc_22481496

# %%
img = obj.save_image()
# Out:
# Total time for saving: 2.791000

# %%
obj.load_model()

# %%
masks = obj._getCoordinate_()
# Out:
# 37

# %%
import cv2
# img_cvt = cv2.imread('D:\Quan\\roboDK\Vision-Machine-collab-Nhan\VIKO_UltraRobot\Record_2024-04-19\\20240419-124548418601-acA2440-35uc_22481496.png')
img_cvt = img.copy()

# %%
masks
# Out:
# [{'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 42309,
#   'bbox': [37, 1851, 232, 194],
#   'predicted_iou': 1.024546504020691,
#   'point_coords': [[267.75, 1888.0]],
#   'stability_score': 0.9812589287757874,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1261912,
#   'bbox': [1698, 142, 749, 1733],
#   'predicted_iou': 1.0200568437576294,
#   'point_coords': [[1950.75, 736.0]],
#   'stability_score': 0.9949110746383667,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 435278,
#   'bbox': [800, 899, 405, 1143],
#   'predicted_iou': 1.012766718864441,
#   'point_coords': [[956.25, 1760.0]],
#   'stability_score': 0.9883260130882263,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 229442,
#   'bbox': [0, 0, 232, 2041],
#   'predicted_iou': 0.999137282371521,
#   'point_coords': [[114.75, 480.0]],
#   'stability_score': 0.9767497181892395,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2518977,
#   'bbox': [204, 0, 2243, 2041],
#   'predicted_iou': 0.9983363151550293,
#   'point_coords': [[1644.75, 992.0]],
#   'stability_score': 0.9767953753471375,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 31825,
#   'bbox': [1802, 0, 219, 148],
#   'predicted_iou': 0.9972031116485596,
#   'point_coords': [[1950.75, 96.0]],
#   'stability_score': 0.9898102879524231,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 641848,
#   'bbox': [1696, 150, 419, 1717],
#   'predicted_iou': 0.9947252869606018,
#   'point_coords': [[2027.25, 1504.0]],
#   'stability_score': 0.9592796564102173,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 432683,
#   'bbox': [2181, 156, 266, 1718],
#   'predicted_iou': 0.9900227785110474,
#   'point_coords': [[2256.75, 1376.0]],
#   'stability_score': 0.9815676808357239,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 36644,
#   'bbox': [266, 1793, 169, 252],
#   'predicted_iou': 0.9885199666023254,
#   'point_coords': [[267.75, 2016.0]],
#   'stability_score': 0.9827142953872681,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 479977,
#   'bbox': [41, 771, 408, 1269],
#   'predicted_iou': 0.9867566823959351,
#   'point_coords': [[114.75, 1760.0]],
#   'stability_score': 0.9792361855506897,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 15510,
#   'bbox': [802, 1447, 77, 323],
#   'predicted_iou': 0.9845829606056213,
#   'point_coords': [[803.25, 1696.0]],
#   'stability_score': 0.9837678670883179,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4381,
#   'bbox': [122, 777, 89, 66],
#   'predicted_iou': 0.9793825149536133,
#   'point_coords': [[191.25, 800.0]],
#   'stability_score': 0.9868540167808533,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 7001,
#   'bbox': [109, 350, 100, 103],
#   'predicted_iou': 0.9778788685798645,
#   'point_coords': [[191.25, 416.0]],
#   'stability_score': 0.9862450361251831,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 368170,
#   'bbox': [307, 787, 497, 1255],
#   'predicted_iou': 0.9759505391120911,
#   'point_coords': [[726.75, 2016.0]],
#   'stability_score': 0.9795171022415161,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 367506,
#   'bbox': [435, 1006, 757, 1036],
#   'predicted_iou': 0.9756141901016235,
#   'point_coords': [[726.75, 1952.0]],
#   'stability_score': 0.9791517853736877,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1520989,
#   'bbox': [220, 5, 2227, 1043],
#   'predicted_iou': 0.97428959608078,
#   'point_coords': [[1415.25, 928.0]],
#   'stability_score': 0.9538909196853638,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 367876,
#   'bbox': [435, 1006, 369, 1036],
#   'predicted_iou': 0.9724549055099487,
#   'point_coords': [[650.25, 2016.0]],
#   'stability_score': 0.9798299074172974,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 211607,
#   'bbox': [980, 1021, 225, 1020],
#   'predicted_iou': 0.9713220000267029,
#   'point_coords': [[1032.75, 1120.0]],
#   'stability_score': 0.9679989218711853,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ...,  True,  True,  True],
#          [False, False, False, ...,  True,  True,  True],
#          [False, False, False, ...,  True,  True,  True],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 31970,
#   'bbox': [2208, 0, 239, 151],
#   'predicted_iou': 0.9701154232025146,
#   'point_coords': [[2333.25, 32.0]],
#   'stability_score': 0.9762595891952515,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ...,  True,  True,  True],
#          [False, False, False, ...,  True,  True,  True],
#          [False, False, False, ...,  True,  True,  True],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 31889,
#   'bbox': [2071, 0, 376, 151],
#   'predicted_iou': 0.9639396667480469,
#   'point_coords': [[2409.75, 32.0]],
#   'stability_score': 0.976866602897644,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1298,
#   'bbox': [988, 136, 41, 37],
#   'predicted_iou': 0.9630559086799622,
#   'point_coords': [[1032.75, 160.0]],
#   'stability_score': 0.9592145085334778,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 22949,
#   'bbox': [294, 1003, 151, 185],
#   'predicted_iou': 0.9619494676589966,
#   'point_coords': [[420.75, 1120.0]],
#   'stability_score': 0.9605038166046143,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 124580,
#   'bbox': [1236, 1868, 1211, 175],
#   'predicted_iou': 0.9615095257759094,
#   'point_coords': [[1874.25, 2016.0]],
#   'stability_score': 0.9583414793014526,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 13719,
#   'bbox': [200, 1095, 79, 202],
#   'predicted_iou': 0.9607694745063782,
#   'point_coords': [[267.75, 1120.0]],
#   'stability_score': 0.9719069004058838,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 14767,
#   'bbox': [2012, 1507, 65, 321],
#   'predicted_iou': 0.9598343968391418,
#   'point_coords': [[2027.25, 1696.0]],
#   'stability_score': 0.9702269434928894,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1400,
#   'bbox': [926, 515, 41, 42],
#   'predicted_iou': 0.9581153392791748,
#   'point_coords': [[956.25, 544.0]],
#   'stability_score': 0.9808781743049622,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 368740,
#   'bbox': [435, 1006, 1984, 1035],
#   'predicted_iou': 0.9571830630302429,
#   'point_coords': [[497.25, 1184.0]],
#   'stability_score': 0.9818243980407715,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 124444,
#   'bbox': [1608, 1868, 839, 175],
#   'predicted_iou': 0.955051600933075,
#   'point_coords': [[1874.25, 1952.0]],
#   'stability_score': 0.9611431956291199,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 26249,
#   'bbox': [2021, 0, 189, 148],
#   'predicted_iou': 0.9545272588729858,
#   'point_coords': [[2103.75, 96.0]],
#   'stability_score': 0.9825436472892761,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 605354,
#   'bbox': [1201, 1035, 1246, 1007],
#   'predicted_iou': 0.9510937333106995,
#   'point_coords': [[1491.75, 1888.0]],
#   'stability_score': 0.9521699547767639,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1410,
#   'bbox': [1235, 95, 42, 42],
#   'predicted_iou': 0.9505494832992554,
#   'point_coords': [[1262.25, 96.0]],
#   'stability_score': 0.9866291284561157,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 30909,
#   'bbox': [807, 897, 382, 136],
#   'predicted_iou': 0.9491966366767883,
#   'point_coords': [[1032.75, 992.0]],
#   'stability_score': 0.9558456540107727,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2038,
#   'bbox': [0, 1103, 70, 43],
#   'predicted_iou': 0.9490139484405518,
#   'point_coords': [[38.25, 1120.0]],
#   'stability_score': 0.981517493724823,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1646,
#   'bbox': [166, 1082, 36, 71],
#   'predicted_iou': 0.9456357955932617,
#   'point_coords': [[191.25, 1120.0]],
#   'stability_score': 0.9824879169464111,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3077,
#   'bbox': [2121, 1731, 63, 59],
#   'predicted_iou': 0.944400429725647,
#   'point_coords': [[2180.25, 1760.0]],
#   'stability_score': 0.9797492623329163,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 245042,
#   'bbox': [39, 770, 244, 1271],
#   'predicted_iou': 0.9436719417572021,
#   'point_coords': [[191.25, 1056.0]],
#   'stability_score': 0.9508416652679443,
#   'crop_box': [0, 0, 2448, 2048]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 201358,
#   'bbox': [199, 792, 250, 1053],
#   'predicted_iou': 0.927160918712616,
#   'point_coords': [[344.25, 992.0]],
#   'stability_score': 0.966438353061676,
#   'crop_box': [0, 0, 2448, 2048]}]

# %%
import numpy as np
img_arr = np.asarray(img)

# %%
for mask in masks:
    x, y, w, h = mask['bbox']
    if (h == 1733):
        print(mask['bbox'])
        cv2.rectangle(img_arr, (x, y), (x+w, y + h),   (0, 255, 0), thickness= 10)
    # cv2.imshow('Show', img_cvt)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()
# Out:
# [1698, 142, 749, 1733]

# %%
import matplotlib.pyplot as plt
plt.imshow(img_arr)

# %%
plt.savefig('Record_2024-04-19/Masks1.png')

# %%
obj._end_()
