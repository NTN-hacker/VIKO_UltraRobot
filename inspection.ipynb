# %%
# import aspose.zip as az
import os
import shutil
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import json

# %%
a = {'a': 2, 'b': 1, 'c': 1}

# %%
a = {'a': 2, 'b': 1, 'c': 1}
'a' = 2/(2+1+1)
'b' = 1/(2+1+1)
'c' = 1/(2+1+1)

a = {'a': 50, 'b': 25, 'c': 25}

# %%
total = sum(a.values())
for key in a:
    a[key] = (a[key] / total) * 100
